# %%
import pandas as pd

# %%
# mostramos todos las columnas sin la limitacion de espacio
pd.set_option('display.max_columns', None)

#añadimos el csv al dataFrame
df_sharks = pd.read_csv("attacks.csv", encoding="ISO-8859-1")

# %%
df_sharks[(df_sharks.Country == "USA") & (df_sharks.Type == "Unprovoked")]
# Out:
#        Case Number                Date    Year        Type Country  \
# 1       2018.06.18         18-Jun-2018  2018.0  Unprovoked     USA
# 7       2018.05.27         27-May-2018  2018.0  Unprovoked     USA
# 8     2018.05.26.b         26-May-2018  2018.0  Unprovoked     USA
# 9     2018.05.26.a         26-May-2018  2018.0  Unprovoked     USA
# 11      2018.05.21         21-May-2018  2018.0  Unprovoked     USA
# ...            ...                 ...     ...         ...     ...
# 6249       ND.0056         Before 1958     0.0  Unprovoked     USA
# 6283       ND.0019         Before 1921     0.0  Unprovoked     USA
# 6288       ND.0014  Before 17-Jul-1916     0.0  Unprovoked     USA
# 6292       ND.0010          Circa 1862     0.0  Unprovoked     USA
# 6299       ND.0003           1900-1905     0.0  Unprovoked     USA
#
#                  Area                                           Location  \
# 1             Georgia                     St. Simon Island, Glynn County
# ...

# %%
df_sharks["Type"].unique()
# Out:
# array(['Boating', 'Unprovoked', 'Invalid', 'Provoked', 'Questionable',
#        'Sea Disaster', nan, 'Boat', 'Boatomg'], dtype=object)

# %%
len(df_sharks["Type"].unique())
# Out:
# 9

# %%
df_sharks[(df_sharks.Type == "Unprovoked")]
# Out:
#        Case Number         Date    Year        Type             Country  \
# 1       2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 3       2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 5     2018.06.03.b  03-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 6     2018.06.03.a  03-Jun-2018  2018.0  Unprovoked              BRAZIL
# 7       2018.05.27  27-May-2018  2018.0  Unprovoked                 USA
# ...            ...          ...     ...         ...                 ...
# 6297       ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298       ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299       ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300       ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301       ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                                           Location  \
# ...

# %%
df_sharks.groupby(["Country","Type", "Activity"]).size().sort_values(ascending=False)
# Out:
# Country       Type        Activity
# USA           Unprovoked  Surfing                             528
#                           Swimming                            277
# AUSTRALIA     Unprovoked  Surfing                             182
#                           Swimming                            130
# SOUTH AFRICA  Unprovoked  Surfing                              95
#                                                              ...
# INDIA         Unprovoked  Washed off catamaran in the surf      1
#                           Wading                                1
#                           Swimming or surfing                   1
#                           Standing                              1
# YEMEN         Unprovoked  Swimming at side of small boat        1
# Length: 2384, dtype: int64

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
# obtener registro primera fila
df.iloc[0]
# Out:
# Case Number                                                      2018.06.25
# Date                                                            25-Jun-2018
# Year                                                                 2018.0
# Type                                                                Boating
# Country                                                                 USA
# Area                                                             California
# Location                                        Oceanside, San Diego County
# Activity                                                           Paddling
# Name                                                            Julie Wolfe
# Sex                                                                       F
# Age                                                                      57
# Injury                    No injury to occupant, outrigger canoe and pad...
# ...

# %%
df.corr()
# Out:
#                     Year  original order
# Year            1.000000        0.388638
# original order  0.388638        1.000000

# %%
df.iloc[:, 0] # Primera columna
# Out:
# 0        2018.06.25
# 1        2018.06.18
# 2        2018.06.09
# 3        2018.06.08
# 4        2018.06.04
#             ...
# 25718           NaN
# 25719           NaN
# 25720           NaN
# 25721           NaN
# 25722            xx
# Name: Case Number, Length: 25723, dtype: object

# %%
shark_activity_atack = df.Activity[df.Activity == "Surfing"]

# %%
copiadf = df.copy(deep=True)

# %%
copiadf.drop(["Case Number"], axis=1, inplace=True)

# %%
copiadf.drop(["original order"], axis=1, inplace=True)

# %%
copiadf.dropna(how="all", inplace=True)

# %%
copiadf
# Out:
#              Date    Year        Type             Country               Area  \
# 0     25-Jun-2018  2018.0     Boating                 USA         California
# 1     18-Jun-2018  2018.0  Unprovoked                 USA            Georgia
# 2     09-Jun-2018  2018.0     Invalid                 USA             Hawaii
# 3     08-Jun-2018  2018.0  Unprovoked           AUSTRALIA    New South Wales
# 4     04-Jun-2018  2018.0    Provoked              MEXICO             Colima
# ...           ...     ...         ...                 ...                ...
# 6297  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6298  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6299    1900-1905     0.0  Unprovoked                 USA     North Carolina
# 6300    1883-1889     0.0  Unprovoked              PANAMA                NaN
# 6301    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
# ...

# %%
# ------------------------------------------------------------------------------------------

# %%
# ------------------------------------------------------------------------------------------

# %%
shark_activity_provoked = copiadf.Type[copiadf.Type == "Unprovoked"]

# %%
# Establezcon como indice la columna Pais
copiadf_country_index = copiadf.set_index("Country")

# %%
copiadf_country_index.loc[["USA"]]
# Out:
#                        Date    Year        Type             Area  \
# Country
# USA             25-Jun-2018  2018.0     Boating       California
# USA             18-Jun-2018  2018.0  Unprovoked          Georgia
# USA             09-Jun-2018  2018.0     Invalid           Hawaii
# USA             27-May-2018  2018.0  Unprovoked          Florida
# USA             26-May-2018  2018.0  Unprovoked          Florida
# ...                     ...     ...         ...              ...
# USA             Before 1958     0.0  Unprovoked          Florida
# USA             Before 1921     0.0  Unprovoked          Florida
# USA      Before 17-Jul-1916     0.0  Unprovoked  North Carolina
# USA              Circa 1862     0.0  Unprovoked           Hawaii
# USA               1900-1905     0.0  Unprovoked   North Carolina
#
#                                                   Location  Activity  \
# Country
# USA                            Oceanside, San Diego County  Paddling
# ...

# %%
agrupado = shark_activity_provoked.groupby(copiadf["Country"])
