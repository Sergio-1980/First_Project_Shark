# %%
import pandas as pd
import numpy as np

# %%
# mostramos todos las columnas sin la limitacion de espacio
pd.set_option('display.max_columns', None)
#añadimos el csv al dataFrame
df_sharks_paises_fallecidos = pd.read_csv("attacks.csv", encoding="ISO-8859-1")

# %%
# Elimino las columnas que no me son necesarias
df_sharks_paises_fallecidos.drop(["Case Number"], axis=1, inplace=True)
df_sharks_paises_fallecidos.drop(["Date"], axis=1, inplace=True)
df_sharks_paises_fallecidos.drop(["Year"], axis=1, inplace=True)
df_sharks_paises_fallecidos.drop(["Type"], axis=1, inplace=True)
df_sharks_paises_fallecidos.drop(["Activity"], axis=1, inplace=True)
df_sharks_paises_fallecidos.drop(["Name"], axis=1, inplace=True)
df_sharks_paises_fallecidos.drop(["Sex "], axis=1, inplace=True)
df_sharks_paises_fallecidos.drop(["Age"], axis=1, inplace=True)
df_sharks_paises_fallecidos.drop(["Injury"], axis=1, inplace=True)
df_sharks_paises_fallecidos.drop(["Time"], axis=1, inplace=True)
df_sharks_paises_fallecidos.drop(["Species "], axis=1, inplace=True)
df_sharks_paises_fallecidos.drop(["Investigator or Source"], axis=1, inplace=True)
df_sharks_paises_fallecidos.drop(["pdf"], axis=1, inplace=True)
df_sharks_paises_fallecidos.drop(["href formula"], axis=1, inplace=True)
df_sharks_paises_fallecidos.drop(["href"], axis=1, inplace=True)
df_sharks_paises_fallecidos.drop(["Case Number.1"], axis=1, inplace=True)
df_sharks_paises_fallecidos.drop(["Case Number.2"], axis=1, inplace=True)
df_sharks_paises_fallecidos.drop(["original order"], axis=1, inplace=True)
df_sharks_paises_fallecidos.drop(["Unnamed: 22"], axis=1, inplace=True)
df_sharks_paises_fallecidos.drop(["Unnamed: 23"], axis=1, inplace=True)

# %%
df_sharks_paises_fallecidos.dropna(how="all", inplace=True)

# %%
df_sharks_paises_fallecidos
# Out:
#                  Country               Area  \
# 0                    USA         California
# 1                    USA            Georgia
# 2                    USA             Hawaii
# 3              AUSTRALIA    New South Wales
# 4                 MEXICO             Colima
# ...                  ...                ...
# 6297           AUSTRALIA  Western Australia
# 6298           AUSTRALIA  Western Australia
# 6299                 USA     North Carolina
# 6300              PANAMA                NaN
# 6301  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location Fatal (Y/N)
# 0             Oceanside, San Diego County           N
# 1          St. Simon Island, Glynn County           N
# 2                            Habush, Oahu           N
# 3                      Arrawarra Headland           N
# 4                                La Ticla           N
# ...                                   ...         ...
# ...

# %%
df_sharks_paises_fallecidos.groupby(["Country","Area", "Location", "Fatal (Y/N)"]).size().sort_values(ascending=False)
# Out:
# Country    Area             Location                          Fatal (Y/N)
# USA        Florida          New Smyrna Beach, Volusia County  N              160
#                             Daytona Beach, Volusia County     N               30
#                             Ponce Inlet, Volusia County       N               20
#                             Melbourne Beach, Brevard County   N               17
#            South Carolina   Myrtle Beach, Horry County        N               16
#                                                                             ...
# INDONESIA  Java             Lorok Bay                         Y                1
#            Maluku Province  Aru Islands                       Y                1
#            Moluccas         South Aroo Island                 Y                1
#            North Sumatra    Near Belawan                      Y                1
# YEMEN      Socotra Islands  Socotra                           Y                1
# ...

# %%
df_sharks_paises_fallecidos[(df_sharks_paises_fallecidos.Country == "USA") & (df_sharks_paises_fallecidos["Fatal (Y/N)"] == "Y")].count()
# Out:
# Country        186
# Area           185
# Location       173
# Fatal (Y/N)    186
# dtype: int64

# %%
# Buscamos NaN
pd.isnull(df_sharks_paises_fallecidos)
# Out:
#       Country   Area  Location  Fatal (Y/N)
# 0       False  False     False        False
# 1       False  False     False        False
# 2       False  False     False        False
# 3       False  False     False        False
# 4       False  False     False        False
# ...       ...    ...       ...          ...
# 6297    False  False     False        False
# 6298    False  False      True        False
# 6299    False  False     False        False
# 6300    False   True     False        False
# 6301    False  False     False        False
#
# [6299 rows x 4 columns]

# %%
df_sharks_paises_fallecidos.isnull().any()
# Out:
# Country        True
# Area           True
# Location       True
# Fatal (Y/N)    True
# dtype: bool

# %%
df_sharks_paises_fallecidos.isnull().sum()
# Out:
# Country         47
# Area           452
# Location       537
# Fatal (Y/N)    536
# dtype: int64

# %%
df_sharks_paises_fallecidos.describe().T
# Out:
#             count unique                               top  freq
# Country      6252    212                               USA  2229
# Area         5847    825                           Florida  1037
# Location     5762   4108  New Smyrna Beach, Volusia County   163
# Fatal (Y/N)  5763      8                                 N  4293

# %%
# Reemplazo los valores de nan por None en las columnas
df_sharks_paises_fallecidos["Country"].replace(np.nan, "None", inplace=True)
df_sharks_paises_fallecidos["Area"].replace(np.nan, "None", inplace=True)
df_sharks_paises_fallecidos["Location"].replace(np.nan, "None", inplace=True)
df_sharks_paises_fallecidos["Fatal (Y/N)"].replace(np.nan, "None", inplace=True)

# %%
df_sharks_paises_fallecidos.isnull().sum()
# Out:
# Country        0
# Area           0
# Location       0
# Fatal (Y/N)    0
# dtype: int64

# %%
df_sharks_paises_fallecidos
# Out:
#                  Country               Area  \
# 0                    USA         California
# 1                    USA            Georgia
# 2                    USA             Hawaii
# 3              AUSTRALIA    New South Wales
# 4                 MEXICO             Colima
# ...                  ...                ...
# 6297           AUSTRALIA  Western Australia
# 6298           AUSTRALIA  Western Australia
# 6299                 USA     North Carolina
# 6300              PANAMA               None
# 6301  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location Fatal (Y/N)
# 0             Oceanside, San Diego County           N
# 1          St. Simon Island, Glynn County           N
# 2                            Habush, Oahu           N
# 3                      Arrawarra Headland           N
# 4                                La Ticla           N
# ...                                   ...         ...
# ...

# %%
unicas = {}     # Este es el diccionario que llevará el registro

def es_duplicado(x):
  datos = tuple(x.values)         # Sacar los datos de esa fila
  index = x.name                  # y su índice
  if datos in unicas:             # ¿Estaba en el diccionario?
    return f"Sí, {unicas[datos]}"
  else:
    unicas[datos] = index         # No estaba, tomamos nota de ella
    return "No"

# %%
df_sharks_paises_fallecidos[(df_sharks_paises_fallecidos.Country == "Fiji")]
# Out:
#      Country               Area                     Location Fatal (Y/N)  \
# 299     Fiji         Vanua Levu                         None           Y
# 2751    Fiji         Vanua Levu                         None           N
# 5900    Fiji  Lomaiviti Provine  Levuka Point, Ovalau Island        None
#
#      Duplicado?
# 299          No
# 2751         No
# 5900         No

# %%
#df_sharks_paises_fallecidos["Country"] = df_sharks_paises_fallecidos

# %%
copiadfsharks = df_sharks_paises_fallecidos.copy(deep=True)

# %%
copiadfsharks2 = copiadfsharks.apply(lambda x: x.astype(str).str.upper())

# %%
copiadfsharks2
# Out:
#                  Country               Area  \
# 0                    USA         CALIFORNIA
# 1                    USA            GEORGIA
# 2                    USA             HAWAII
# 3              AUSTRALIA    NEW SOUTH WALES
# 4                 MEXICO             COLIMA
# ...                  ...                ...
# 6297           AUSTRALIA  WESTERN AUSTRALIA
# 6298           AUSTRALIA  WESTERN AUSTRALIA
# 6299                 USA     NORTH CAROLINA
# 6300              PANAMA               NONE
# 6301  CEYLON (SRI LANKA)   EASTERN PROVINCE
#
#                                  Location Fatal (Y/N) Duplicado?
# 0             OCEANSIDE, SAN DIEGO COUNTY           N         NO
# 1          ST. SIMON ISLAND, GLYNN COUNTY           N         NO
# 2                            HABUSH, OAHU           N         NO
# 3                      ARRAWARRA HEADLAND           N         NO
# 4                                LA TICLA           N         NO
# ...

# %%
df_sharks_paises_fallecidos[(df_sharks_paises_fallecidos.Country == "MEXICO")]
# Out:
#      Country                 Area                      Location Fatal (Y/N)  \
# 4     MEXICO               Colima                      La Ticla           N
# 122   MEXICO              Tabasco  Sánchez Magallanes, Cárdenas           N
# 144   MEXICO  Baja California Sur     Los Arbolitos, Cabo Pulmo           Y
# 206   MEXICO                 None              Guadalupe Island        None
# 226   MEXICO                 None              Guadalupe Island        None
# ...      ...                  ...                           ...         ...
# 6024  MEXICO               Oaxaca            Tehuantepec Harbor           Y
# 6044  MEXICO                 None                          None           Y
# 6048  MEXICO             Veracruz                     Vera Cruz           Y
# 6052  MEXICO            Vera Cruz                     Vera Cruz           Y
# 6174  MEXICO                 None                          None           N
#
#      Duplicado?
# 4            No
# 122          No
# ...
